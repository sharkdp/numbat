# %%
let A0 = 3 cm
let ω = 20 Hz
let lambda = 1.5 s

fn amplitude(t: Time) -> Length = A0 exp(-t/lambda) × cos(ω t)

# %%
plot amplitude t 0 5 s
# Out:
# <img src="data:image/png;base64,..."/>

# %%
plot amplitude t 0 500 ms
# Out:
# <img src="data:image/png;base64,..."/>

# %%
let T_sun = 5777 K
let h_ = planck_constant

fn spectral_radiance(λ: Length) =
  2 h_ c^2 / λ^5 × 1 / (exp(h_ c / λ k_B T_sun) - 1) -> kW · 1/sr · m^-2 · nm^-1
# Out:
# Identifier is already in use: 'T_sun'.

# %%
plot spectral_radiance λ 1e-3 3 µm
# Out:
# <img src="data:image/png;base64,..."/>
